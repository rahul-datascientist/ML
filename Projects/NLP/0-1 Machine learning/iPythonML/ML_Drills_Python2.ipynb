# %%
# first let's do all of the import statements
import requests
import urllib2
from bs4 import BeautifulSoup
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from collections import defaultdict
from string import punctuation
from heapq import nlargest
from math import log
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
def getWashPostText(url,token):
    # THis function takes the URL of an article in the 
    # Washington Post, and then returns the article minus all 
    # of the crud - HTML, javascript etc. How? By searching for
    # everything that lies between the tags titled 'token'
    # Like most web-scraping, this will only work for urls where
    # we know the structure (eg say all articles in the WashPo are
    # enclosed in <article></article> tags). This will also change from
    # time to time as different HTML formats are employed in the website
    try:
        page = urllib2.urlopen(url).read().decode('utf8')
    except:
        # if unable to download the URL, return title = None, article = None
        return (None,None)
    soup = BeautifulSoup(page)
    if soup is None:
        return (None,None)
    # If we are here, it means the error checks were successful, we were
    # able to parse the page
    text = ""
    if soup.find_all(token) is not None:
        # Search the page for whatever token demarcates the article
        # usually '<article></article>'
        text = ''.join(map(lambda p: p.text, soup.find_all(token)))
        # mush together all the text in the <article></article> tags
        soup2 = BeautifulSoup(text)
        # create a soup of the text within the <article> tags
        if soup2.find_all('p')!=[]:
            # now mush together the contents of what is in <p> </p> tags
            # within the <article>
            text = ''.join(map(lambda p: p.text, soup2.find_all('p')))
    return text, soup.title.text
    # what did we just do? Let's go through and understand
    # finally return the result tuple with the title and the body of the article

# %%
# Now we will do something very very similar, but this time for the New York Times
def getNYTText(url,token):
    response = requests.get(url)
    # THis is an alternative way to get the contents of a URL
    soup = BeautifulSoup(response.content)
    page = str(soup)
    title = soup.find('title').text
    mydivs = soup.findAll("p", {"class":"story-body-text story-content"})
    text = ''.join(map(lambda p:p.text, mydivs))
    return text, title
    # Notice again how important it is to know the structure of the page
    # we are seeking to scrape. If we did not know that articles in the NYT
    # come contained in these tags - an outer tag <p> and an inner tag
    # of class = story-body-text story-content, we would be unable to parse

# %%
# Ok! Now we have a way to extract the contents and title of an individual
# URL. Let's hook this up inside another function that will take the URL
# of an entire section of a newspaper - say the Technology or Sports section
# of a newspaper - and parse all of the URLs for articles linked off that
# section. 
# Btw, these sections also come with plenty of non-news links - 'about',
# how to syndicate etc, so we will employ a little hack - we will consider
# something to be a news article only if the url has a dateline. THis is 
# actually very safe - its pretty much the rule for articles to have a 
# date, and virtually all important newspapers mush this date into the URL.
def scrapeSource(url, magicFrag='2015',scraperFunction=getNYTText,token='None'):
    urlBodies = {}
    request = urllib2.Request(url)
    response = urllib2.urlopen(request)
    soup = BeautifulSoup(response)
    # we are set up with a Soup of the page - now find the links
    # Remember that links are always of the form 
    # <a href='link-url'> link-text </a>
    numErrors = 0
    for a in soup.findAll('a'):
        try:
            url = a['href']
            if( (url not in urlBodies) and 
               ((magicFrag is not None and magicFrag in url) 
               or magicFrag is None)):
                body = scraperFunction(url,token)
                # this line above is important - scraperFunction 
                # refers to the individual scraper function for the 
                # new york times or the washington post etc.
                if body and len(body) > 0:
                    urlBodies[url] = body
                print url
        except:
            numErrors += 1
            # plenty of parse errors happen - links might not
            # be external links, might be malformed and so on -
            # so don't mind if there are exceptions.
    return urlBodies

# %%
# Now for the frequency summarizer class - which we have encountered
# before. To quickly jog our memories - given an (title,article-body) tuple
# the frequency summarizer has easy ways to find the most 'important'
# sentences, and the most important words. How is 'important' defined?
# Important = most frequent, excluding 'stopwords' which are generic
# words like 'the' etc which can be ignored
class FrequencySummarizer:
    def __init__(self,min_cut=0.1,max_cut=0.9):
        # class constructor - takes in min and max cutoffs for 
        # frequency
        self._min_cut = min_cut
        self._max_cut = max_cut
        self._stopwords = set(stopwords.words('english') +
                              list(punctuation) +
                              [u"'s",'"'])
        # notice how the stopwords are a set, not a list. 
        # its easy to go from set to list and vice-versa
        # (simply use the set() and list() functions) - 
        # but conceptually sets are different from lists
        # because sets don't have an order to their elements
        # while lists do
    
    def _compute_frequencies(self,word_sent,customStopWords=None):
        freq = defaultdict(int)
        # we have encountered defaultdict objects before
        if customStopWords is None:
            stopwords = set(self._stopwords)
        else:
            stopwords = set(customStopWords).union(self._stopwords)
        for sentence in word_sent:
            for word in sentence:
                if word not in stopwords:
                    freq[word] += 1
        m = float(max(freq.values()))
        for word in freq.keys():
            freq[word] = freq[word]/m
            if freq[word] >= self._max_cut or freq[word] <= self._min_cut:
                del freq[word]
        return freq
    
    def extractFeatures(self,article,n,customStopWords=None):
        # The article is passed in as a tuple (text, title)
        text = article[0]
        # extract the text
        title = article[1]
        # extract the title
        sentences = sent_tokenize(text)
        # split the text into sentences
        word_sent = [word_tokenize(s.lower()) for s in sentences]
        # split the sentences into words 
        self._freq = self._compute_frequencies(word_sent,customStopWords)
        # calculate the word frequencies using the member function above
        if n < 0:
            # how many features (words) to return? IF the user has
            # asked for a negative number, this is a sign that we don't
            # do any feature selection - we return ALL features
            # THis is feature extraction without any pruning, ie no
            # feature selection (beyond simply picking words as the features)
            return nlargest(len(self._freq_keys()),self._freq,key=self._freq.get)
        else:
            # if the calling function has asked for a subset then
            # return only the 'n' largest features - ie here the most
            # important words (important == frequent, barring stopwords)
            return nlargest(n,self._freq,key=self._freq.get)
        # let's summarize what we did here. 
    
    def extractRawFrequencies(self, article):
        # very similar, except that this method will return the 'raw'
        # frequencies - literally just the word counts
        text = article[0]
        title = article[1]
        sentences = sent_tokenize(text)
        word_sent = [word_tokenize(s.lower()) for s in sentences]
        freq = defaultdict(int)
        for s in word_sent:
            for word in s:
                if word not in self._stopwords:
                    freq[word] += 1
        return freq
    
    def summarize(self, article,n):
        text = article[0]
        title = article[1]
        sentences = sent_tokenize(text)
        word_sent = [word_tokenize(s.lower()) for s in sentences]
        self._freq = self._compute_frequencies(word_sent)
        ranking = defaultdict(int)
        for i,sentence in enumerate(word_sent):
            for word in sentence:
                if word in self._freq:
                    ranking[i] += self._freq[word]
        sentences_index = nlargest(n,ranking,key=ranking.get)

        return [sentences[j] for j in sentences_index]

# %%
urlWashingtonPostNonTech = "https://www.washingtonpost.com/sports"
urlNewYorkTimesNonTech = "https://www.nytimes.com/pages/sports/index.html"
urlWashingtonPostTech = "https://www.washingtonpost.com/business/technology"
urlNewYorkTimesTech = "http://www.nytimes.com/pages/technology/index.html"

washingtonPostTechArticles = scrapeSource(urlWashingtonPostTech,
                                          '2016',
                                         getWashPostText,
                                         'article') 
washingtonPostNonTechArticles = scrapeSource(urlWashingtonPostNonTech,
                                          '2016',
                                         getWashPostText,
                                         'article')
                
                
newYorkTimesTechArticles = scrapeSource(urlNewYorkTimesTech,
                                       '2016',
                                       getNYTText,
                                       None)
newYorkTimesNonTechArticles = scrapeSource(urlNewYorkTimesNonTech,
                                       '2016',
                                       getNYTText,
                                       None)
# Out:
# https://www.washingtonpost.com/news/inspired-life/wp/2016/01/21/my-message-of-pride-a-mothers-newspaper-ad-celebrates-her-sons-coming-out/
# https://www.washingtonpost.com/news/wonk/wp/2016/01/21/how-a-year-and-a-half-of-pension-gains-were-wiped-out-in-just-three-months/
# https://www.washingtonpost.com/news/arts-and-entertainment/wp/2016/01/21/will-smith-joins-his-wife-in-boycotting-the-academy-awards-as-oscarssowhite-backlash-grows/
# https://www.washingtonpost.com/news/worldviews/wp/2016/01/20/these-are-the-worlds-best-countries-sorry-america-youre-number-4/
# https://www.washingtonpost.com/news/early-lead/wp/2016/01/21/meet-kathryn-smith-the-first-full-time-female-assistant-coach-in-nfl-history/
# https://www.washingtonpost.com/news/speaking-of-science/wp/2016/01/21/planet-nine-isnt-the-mythical-nibiru-it-may-not-even-exist/
# https://www.washingtonpost.com/news/post-nation/wp/2016/01/21/disgraced-ex-officer-daniel-holtzclaw-to-be-sentenced-after-sex-crimes-conviction/
# https://www.washingtonpost.com/news/the-switch/wp/2016/01/20/your-internet-provider-is-turning-into-a-data-hungry-tech-company-consumer-groups-warn/
# https://www.washingtonpost.com/news/the-switch/wp/2016/01/21/this-google-map-shows-the-dc-region-cant-handle-an-inch-of-snow/
# https://www.washingtonpost.com/news/the-switch/wp/2016/01/21/why-you-should-look-to-states-not-the-federal-government-to-protect-your-privacy/
# https://www.washingtonpost.com/news/innovations/wp/2016/01/21/a-computer-program-is-writing-new-friends-episodes-are-they-any-good/
# https://www.washingtonpost.com/news/innovations/wp/2016/01/21/global-innovation-may-have-a-1-percent-problem/
# https://www.washingtonpost.com/news/business/wp/2016/01/20/the-tiny-chip-that-could-power-big-changes-in-how-you-shop/
# https://www.washingtonpost.com/news/morning-mix/wp/2016/01/20/her-dying-husband-left-her-the-house-and-the-car-but-he-forgot-the-apple-password/
# https://www.washingtonpost.com/news/the-switch/wp/2016/01/19/apple-is-slightly-more-diverse-than-it-was-last-year/
# https://www.washingtonpost.com/news/the-switch/wp/2016/01/19/why-donald-trump-is-now-targeting-apple-and-its-damn-computers/
# https://www.washingtonpost.com/news/the-switch/wp/2016/01/19/whatsapp-ditches-its-annual-subscription-fee/
# https://www.washingtonpost.com/news/innovations/wp/2016/01/19/what-the-worlds-best-cities-will-look-like-in-2030/
# https://www.washingtonpost.com/news/the-switch/wp/2016/01/19/people-are-still-using-these-terrible-passwords/
# https://www.washingtonpost.com/news/the-switch/wp/2016/01/19/verizon-just-launched-freebee-its-plan-for-sponsored-data/
# https://www.washingtonpost.com/news/innovations/wp/2016/01/19/r-i-p-bitcoin-its-time-to-move-on/
# https://www.washingtonpost.com/business/2016/01/14/0fe6305c-b87e-11e5-829c-26ffb874a18d_story.html
# https://www.washingtonpost.com/business/this-game-can-teach-you-algebra--and-its-enjoyable/2016/01/14/01722c74-b87e-11e5-829c-26ffb874a18d_story.html
# https://www.washingtonpost.com/news/the-switch/wp/2016/01/15/meet-dream-chaser-the-spunky-little-space-plane-that-could/
# https://www.washingtonpost.com/news/the-switch/wp/2016/01/15/you-may-have-forgotten-about-foursquare-which-is-why-they-have-a-new-ceo/
# https://www.washingtonpost.com/video/business/technology/why-the-future-of-tech-living-will-come-to-your-hotel-room-before-your-home/2016/01/15/7127db90-bbc6-11e5-85cd-5ad59bc19432_video.html
# https://www.washingtonpost.com/news/the-switch/wp/2016/01/15/what-to-expect-from-virtual-reality-in-2016/
# https://www.washingtonpost.com/news/the-switch/wp/2016/01/15/should-you-be-afraid-of-cyberattacks-on-nuclear-power-plants/
# https://www.washingtonpost.com/news/wonk/wp/2016/01/20/we-have-a-q-tips-problem/?tid=pm_business_pop_b
# https://www.washingtonpost.com/business/economy/global-stock-slide-spreads-gloom-to-once-high-flying-tech-industry/2016/01/20/0602d1c8-bfa7-11e5-83d4-42e3bceea902_story.html?tid=pm_business_pop_b
# https://www.washingtonpost.com/business/the-bear-market-may-have-already-begun/2016/01/15/f524e948-bba7-11e5-829c-26ffb874a18d_story.html?tid=pm_business_pop_b
# https://www.washingtonpost.com/news/wonk/wp/2016/01/20/the-awkward-question-about-flint-that-no-one-wants-to-answer/?tid=pm_business_pop_b
# https://www.washingtonpost.com/news/wonk/wp/2016/01/20/is-the-stock-market-telling-us-were-headed-for-a-recession/?tid=pm_business_pop_b
# https://www.washingtonpost.com/sports/nba-star-sold-crack-to-help-escape-his-hometown-now-he-wants-to-heal-it/2016/01/19/71130b32-b94d-11e5-b682-4bb4dd403c7d_story.html
# http://www.washingtonpost.com/blogs/dc-sports-bog/wp/2016/01/19/former-nfl-receiver-antwaan-randle-el-regrets-ever-playing-football/
# https://www.washingtonpost.com/news/football-insider/wp/2016/01/20/redskins-left-tackle-trent-williams-withdraws-from-the-pro-bowl/
# https://www.washingtonpost.com/news/early-lead/wp/2016/01/20/packers-jordy-nelson-filled-in-as-third-grade-teacher-while-recovering-from-injury/
# http://www.washingtonpost.com/blogs/early-lead/wp/2016/01/20/want-to-play-madden-on-a-huge-scoreboard-get-recruited-by-auburn/
# https://www.washingtonpost.com/news/sports/wp/2016/01/20/strange-reality-duke-isnt-good-and-potential-for-sad-selection-sunday-grows/
# https://www.washingtonpost.com/news/early-lead/wp/2016/01/05/nfl-rumors-2016/
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2016/01/21/another-snowvechkin-for-the-caps-eerie-parallels-to-2010/
# https://www.washingtonpost.com/sports/capitals/karl-alzner-and-matt-niskanen-have-forged-a-bond-on-and-off-the-ice/2016/01/20/57c4758a-bf8d-11e5-83d4-42e3bceea902_story.html
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2016/01/20/brooks-laich-says-this-caps-team-is-the-best-hes-ever-played-on/
# http://www.washingtonpost.com/blogs/early-lead/wp/2016/01/21/the-winter-storm-could-wreak-havoc-with-the-u-s-sports-schedule/
# https://www.washingtonpost.com/sports/redskins/redskins-must-build-roster-around-a-large-kirk-cousins-contract/2016/01/20/2495013e-bfba-11e5-9443-7074c3645405_story.html
# https://www.washingtonpost.com/news/football-insider/wp/2016/01/20/reviewing-the-2015-redskins-by-position-defensive-line/
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2016/01/20/its-time-to-retire-you-like-that/
# https://www.washingtonpost.com/sports/wizards/wizards-bring-back-the-two-towers-and-nene-and-marcin-gortat-step-up/2016/01/20/08de1a5c-bfce-11e5-9443-7074c3645405_story.html
# https://www.washingtonpost.com/news/nationals-journal/wp/2016/01/20/could-yoenis-cespedes-end-up-in-dc/
# https://www.washingtonpost.com/news/sports/wp/2016/01/21/a-car-crash-could-have-killed-cam-newton-instead-it-fueled-his-joy-for-the-game/
# https://www.washingtonpost.com/news/sports/wp/2016/01/21/the-golden-state-warriors-owe-it-to-themselves-to-chase-72-wins/
# https://www.washingtonpost.com/sports/highschools/swimming-briar-woods-boys-girls-aiming-for-a-conference-title-sweep/2016/01/21/1b42579a-c063-11e5-9443-7074c3645405_story.html
# https://www.washingtonpost.com/news/football-insider/wp/2016/01/21/reviewing-the-2015-redskins-by-position-linebackers/
# https://www.washingtonpost.com/news/nationals-journal/wp/2016/01/21/what-should-be-expected-of-the-nationals-rotation-in-2016/
# https://www.washingtonpost.com/news/recruiting-insider/wp/2016/01/21/coco-kuchins-is-stealing-the-show-for-churchill-girls-basketball/
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2016/01/21/2010-washington-capitals-had-best-record-in-hockey-this-team-is-better/
# https://www.washingtonpost.com/news/early-lead/wp/2016/01/21/rhode-island-liquor-company-trolls-peyton-manning-sends-care-package-to-his-wife/
# https://www.washingtonpost.com/news/early-lead/wp/2016/01/21/lebron-james-might-be-conor-mcgregors-biggest-fan/
# https://www.washingtonpost.com/news/fancy-stats/wp/2016/01/21/tom-brady-has-the-upper-hand-against-peyton-manning/
# https://www.washingtonpost.com/sports/highschools/high-school-basketball-postponements-for-thursday-jan-21/2016/01/21/8edc7e66-c053-11e5-9443-7074c3645405_story.html
# https://www.washingtonpost.com/news/early-lead/wp/2016/01/21/meet-kathryn-smith-the-first-full-time-female-assistant-coach-in-nfl-history/
# https://www.washingtonpost.com/video/sports/highschools/no3-gonzaga-pulls-off-the-upset-over-no1-dematha-73-70/2016/01/21/9bcc030c-c059-11e5-98c8-7fab78677d51_video.html
# https://www.washingtonpost.com/news/wizards-insider/wp/2016/01/21/wizards-finally-faced-an-nba-team-more-injured-than-they-are/
# https://www.washingtonpost.com/news/capitals-insider/wp/2016/01/21/weekend-caps-games-still-on-as-scheduled-despite-tjsnowshie/
# https://www.washingtonpost.com/news/early-lead/wp/2016/01/21/tennessee-school-officials-go-to-court-as-horrific-rape-details-emerge/
# https://www.washingtonpost.com/news/early-lead/wp/2016/01/21/the-winter-storm-could-wreak-havoc-with-the-u-s-sports-schedule/
# https://www.washingtonpost.com/news/fancy-stats/wp/2016/01/21/ranking-the-most-valuable-units-for-patriots-broncos-cardinals-and-panthers/
# https://www.washingtonpost.com/news/fancy-stats/wp/2016/01/21/here-is-who-will-work-best-in-chip-kellys-system/
# https://www.washingtonpost.com/news/early-lead/wp/2016/01/21/deflategate-ii-nah-the-pats-chiefs-refs-simply-left-the-balls-and-gauges-at-their-hotel/
# https://www.washingtonpost.com/news/sports/wp/2016/01/21/jessica-mendoza-and-sunday-night-baseball/
# https://www.washingtonpost.com/news/early-lead/wp/2016/01/21/meet-kathryn-smith-the-first-full-time-female-assistant-coach-in-nfl-history/?tid=pm_sports_pop_b
# https://www.washingtonpost.com/news/nationals-journal/wp/2016/01/20/could-yoenis-cespedes-end-up-in-dc/?tid=pm_sports_pop_b
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2016/01/21/another-snowvechkin-for-the-caps-eerie-parallels-to-2010/?tid=pm_sports_pop_b
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2016/01/21/redskins-trent-murphy-joined-his-not-so-little-brother-for-a-slumber-party-with-jim-harbaugh/?tid=pm_sports_pop_b
# https://www.washingtonpost.com/news/sports/wp/2016/01/21/the-golden-state-warriors-owe-it-to-themselves-to-chase-72-wins/?tid=pm_sports_pop_b
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2016/01/21/redskins-trent-murphy-joined-his-not-so-little-brother-for-a-slumber-party-with-jim-harbaugh/
# https://www.washingtonpost.com/news/dc-sports-bog/wp/2016/01/20/redskins-defensive-line-gives-3600-bottles-of-water-to-help-flint-mi/
# https://www.washingtonpost.com/news/early-lead/wp/2016/01/21/cleveland-radio-host-has-some-unbelievably-sexist-thoughts-on-female-coaches/
# https://www.washingtonpost.com/news/fancy-stats/wp/2016/01/20/the-two-most-valuable-players-in-the-nba-are-steph-curry-and-j-j-redick/
# https://www.washingtonpost.com/news/football-insider/wp/2016/01/21/a-closer-look-at-how-deangelo-hall-performed-after-transitioning-to-safety/
# https://www.washingtonpost.com/news/football-insider/wp/2016/01/20/redskins-quinton-dunbar-the-whole-year-felt-like-a-dream/
# https://www.washingtonpost.com/news/nationals-journal/wp/2016/01/19/on-the-nationals-payroll-30-million-smaller-than-it-was-at-seasons-end/
# https://www.washingtonpost.com/news/nationals-journal/wp/2016/01/15/nationals-avoid-arbitration-with-anthony-rendon/
# https://www.washingtonpost.com/news/capitals-insider/wp/2016/01/20/as-his-defensive-partners-change-taylor-chorney-remains-consistent/
# https://www.washingtonpost.com/news/capitals-insider/wp/2016/01/19/capitals-vs-blue-jackets-game-46-discussion-thread/
# https://www.washingtonpost.com/news/capitals-insider/wp/2016/01/19/john-carlson-practices-with-caps-but-wont-play-against-columbus/
# https://www.washingtonpost.com/news/wizards-insider/wp/2016/01/20/wizards-vs-heat-game-41-discussion-thread/
# https://www.washingtonpost.com/news/wizards-insider/wp/2016/01/20/alan-anderson-to-miss-another-few-weeks-before-making-season-debut-with-wizards/
# https://www.washingtonpost.com/news/wizards-insider/wp/2016/01/19/in-22-games-wizards-have-more-losses-at-home-than-all-of-last-season/
# https://www.washingtonpost.com/news/soccer-insider/wp/2016/01/21/d-c-united-goalkeeper-bill-hamid-will-miss-4-6-months-with-knee-injury/
# https://www.washingtonpost.com/news/soccer-insider/wp/2016/01/20/how-much-does-u-s-soccer-coach-jurgen-klinsmann-make-new-tax-records-offer-details/
# https://www.washingtonpost.com/news/soccer-insider/wp/2016/01/19/what-will-d-c-uniteds-new-stadium-look-like-the-latest-renderings-are-out/
# https://www.washingtonpost.com/news/soccer-insider/wp/2016/01/19/d-c-united-selects-ohio-state-defender-in-mls-draft/
# https://www.washingtonpost.com/news/terrapins-insider/wp/2016/01/20/maryland-receives-commitment-from-florida-running-back-laderrien-wilson/
# https://www.washingtonpost.com/news/terrapins-insider/wp/2016/01/20/maryland-releases-contract-details-for-scott-shafer-walt-bell/
# https://www.washingtonpost.com/news/terrapins-insider/wp/2016/01/20/former-maryland-lacrosse-coach-bud-beardmore-dies-at-76/
# https://www.washingtonpost.com/news/terrapins-insider/wp/2016/01/20/postgame-marylands-defense-is-the-difference-in-ugly-overtime-win-over-northwestern/
# http://www.nytimes.com/2016/01/21/technology/jack-dorsey-juggles-twitter-and-square-both-caught-in-downdraft.html?ref=technology
# http://www.nytimes.com/2016/01/22/technology/personaltech/editing-a-gmail-inbox-trip-bundle.html?ref=technology
# http://bits.blogs.nytimes.com/2016/01/21/daily-report-mr-dorseys-companies-go-on-a-wild-stock-market-ride/?ref=technology
# http://www.nytimes.com/2016/01/22/technology/airbnb-takes-its-case-to-us-mayors-conference.html?ref=technology
# http://www.nytimes.com/2016/01/24/magazine/judge-john-hodgman-on-tech-firm-snacks.html?ref=technology
# http://www.nytimes.com/2016/01/21/style/where-wearable-technology-ends-up-hint-not-your-wrist.html?ref=technology
# http://www.nytimes.com/2016/01/21/arts/television/review-dark-net-explores-the-digital-ages-toll-on-us.html?ref=technology
# http://www.nytimes.com/2016/01/21/technology/personaltech/video-feature-quantified-self-apps-to-help-track-habits-and-identify-patterns.html?ref=technology
# http://www.nytimes.com/2016/01/21/technology/personaltech/apps-to-manage-passwords-so-they-are-harder-to-crack-than-password.html?ref=technology
# http://bits.blogs.nytimes.com/2016/01/20/daily-report-ibm-caught-between-the-old-and-the-new/?ref=technology
# http://www.nytimes.com/2016/01/21/technology/techs-frightful-5-will-dominate-digital-life-for-foreseeable-future.html?ref=technology
# http://www.nytimes.com/2016/01/20/world/asia/china-us-college-application.html?ref=technology
# http://www.nytimes.com/2016/01/20/business/dealbook/microchip-technology-to-buy-atmel-for-nearly-3-6-billion.html?ref=technology
# http://www.nytimes.com/2016/01/20/business/dealbook/practice-fusion-said-to-hire-jpmorgan-chase-to-explore-ipo.html?ref=technology
# http://www.nytimes.com/2016/01/20/business/dealbook/expect-some-unicorns-to-lose-their-horns-and-it-wont-be-pretty.html?ref=technology
# http://www.nytimes.com/2016/01/20/business/international/china-startups-investment.html?ref=technology
# http://www.nytimes.com/2016/01/20/business/media/netflix-faces-a-us-slowdown-despite-global-growth.html?ref=technology
# http://www.nytimes.com/2016/01/20/science/advanced-nuclear-reactors-department-of-energy.html?ref=technology
# http://www.nytimes.com/2016/01/20/technology/microsoft-acquires-minecraftedu-tailored-for-schools.html?ref=technology
# http://www.nytimes.com/2016/01/20/technology/twitter-outage.html?ref=technology
# http://www.nytimes.com/2016/01/14/technology/personaltech/video-feature-some-standouts-at-the-international-ces.html?ref=technology
# http://www.nytimes.com/2016/01/14/technology/personaltech/gear-for-the-next-level-of-mobile-games.html?ref=technology
# http://www.nytimes.com/2016/01/21/technology/personaltech/posting-animated-gifs-on-facebook.html?ref=technology
# http://www.nytimes.com/2016/01/20/technology/personaltech/sticking-with-windows-7.html?ref=technology
# http://www.nytimes.com/2016/01/07/technology/personaltech/ces-4k-television.html?ref=technology
# http://www.nytimes.com/2016/01/15/technology/personaltech/amazon-prime-video-home-and-away.html?ref=technology
# http://www.nytimes.com/2016/01/14/technology/personaltech/adding-menus-and-buttons-to-firefox.html?ref=technology
# http://www.nytimes.com/2016/01/13/technology/personaltech/picking-a-windows-10-security-package.html?ref=technology
# https://medium.com/@invoker/5-big-changes-coming-to-social-media-in-2016-1549ea9c4670#.j6lxdpgng
# http://nymag.com/daily/intelligencer/2016/01/good-bye-to-all-that-twitter.html#
# http://www.nytimes.com/2016/01/21/technology/techs-frightful-5-will-dominate-digital-life-for-foreseeable-future.html?src=me
# http://www.nytimes.com/2016/01/21/technology/personaltech/apps-to-manage-passwords-so-they-are-harder-to-crack-than-password.html?src=me
# http://www.nytimes.com/2016/01/20/technology/personaltech/sticking-with-windows-7.html?src=me
# http://www.nytimes.com/2016/01/20/technology/microsoft-acquires-minecraftedu-tailored-for-schools.html?src=me
# http://bits.blogs.nytimes.com/2016/01/20/daily-report-ibm-caught-between-the-old-and-the-new/?src=me
# http://www.nytimes.com/2016/01/21/technology/personaltech/video-feature-quantified-self-apps-to-help-track-habits-and-identify-patterns.html?src=me
# http://www.nytimes.com/2016/01/18/technology/education-technology-graduates-from-the-classroom-to-the-boardroom.html?src=me
# http://bits.blogs.nytimes.com/2016/01/19/microsoft-to-donate-1-billion-in-cloud-services-to-nonprofits-and-researchers/?src=me
# http://www.nytimes.com/2016/01/18/technology/strat-o-matic-builds-out-its-digital-game-roster.html?src=me
# http://www.nytimes.com/2016/01/19/technology/upstarts-are-leading-the-fintech-movement-and-banks-take-heed.html?src=me
# http://www.nytimes.com/2016/01/21/technology/techs-frightful-5-will-dominate-digital-life-for-foreseeable-future.html?src=mv
# http://www.nytimes.com/2016/01/21/technology/personaltech/apps-to-manage-passwords-so-they-are-harder-to-crack-than-password.html?src=mv
# http://www.nytimes.com/2016/01/21/technology/jack-dorsey-juggles-twitter-and-square-both-caught-in-downdraft.html?src=mv
# http://www.nytimes.com/2016/01/20/technology/personaltech/sticking-with-windows-7.html?src=mv
# http://bits.blogs.nytimes.com/2016/01/19/microsoft-to-donate-1-billion-in-cloud-services-to-nonprofits-and-researchers/?src=mv
# http://www.nytimes.com/2016/01/19/technology/upstarts-are-leading-the-fintech-movement-and-banks-take-heed.html?src=mv
# http://www.nytimes.com/2016/01/20/technology/ibm-reports-declines-in-fourth-quarter-profit-and-revenue-despite-gains-in-new-fields.html?src=mv
# http://bits.blogs.nytimes.com/2016/01/20/daily-report-ibm-caught-between-the-old-and-the-new/?src=mv
# http://bits.blogs.nytimes.com/2016/01/20/deezer-raises-109-million-after-postponing-i-p-o/?src=mv
# http://www.nytimes.com/2016/01/22/sports/tennis/lleyton-hewitt-ends-singles-career-australian-open.html?ref=sports
# http://www.nytimes.com/2016/01/22/sports/tennis/fernando-verdasco-rafael-nadal-australian-open.html?ref=sports
# http://www.nytimes.com/2016/01/22/sports/tennis/naomi-osaka-australian-open-win-elina-svitolina-japan.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/football/among-nfl-coaches-a-lack-of-diversity-trickles-up.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/basketball/derrick-williams-new-york-knicks-beat-utah-jazz.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/basketball/cavaliers-coming-off-a-drubbing-dish-out-punishment-against-the-nets.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/baseball/mets-add-antonio-bastardo-to-bullpen.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/tennis/eugenie-bouchard-exits-australian-open-knowing-a-full-comeback-will-take-time.html?ref=sports
# http://www.nytimes.com/aponline/2016/01/21/sports/tennis/ap-ten-australian-open.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/ncaabasketball/big-5-teams-cap-milestone-with-a-throwback-doubleheader.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/ncaabasketball/college-basketball-roundup.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/soccer/nycfcs-patrick-vieira-acknowledges-long-learning-process.html?ref=sports
# http://www.nytimes.com/2016/01/20/sports/soccer/barcelona-sporting-club-ecuador.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/hockey/john-scott-is-neither-in-the-nhl-nor-a-star.html?ref=sports
# http://www.nytimes.com/2016/01/20/sports/hockey/nhl-this-week-a-western-showdown-and-a-finals-rematch.html?ref=sports
# http://www.nytimes.com/2016/01/19/sports/football/nfl-playoffs-powerful-survivors-have-their-weaknesses.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/football/chip-kelly-nfl-roundup.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/basketball/nba-roundup.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/autoracing/roush-fenway-racing-makes-personnel-changes-in-push-to-catch-up.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/hockey/blues-edge-the-red-wings.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/ncaafootball/passer-puts-baseball-aside.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/agency-to-select-experts.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/baseball/yankees-support-pitcher.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/soccer/reserves-lift-liverpool.html?ref=sports
# http://www.nytimes.com/2016/01/20/sports/baseball/pete-rose-to-enter-cincinnati-reds-hall-of-fame.html?ref=sports
# http://www.nytimes.com/2016/01/20/books/caitlyn-jenner-to-publish-a-memoir-about-her-transformation.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/basketball/how-the-nba-3-point-shot-went-from-gimmick-to-game-changer.html?ref=sports
# http://www.nytimes.com/2016/01/19/sports/tennis/tenniss-watchdog-seems-to-operate-in-the-dark.html?ref=sports
# http://www.nytimes.com/2016/01/22/sports/cricket/domestic-twenty20-leagues-changing-cricket-culture.html?ref=sports
# http://www.nytimes.com/2016/01/18/technology/strat-o-matic-builds-out-its-digital-game-roster.html?ref=sports
# http://www.nytimes.com/2016/01/19/sports/basketball/knicks-kristaps-porzingis-precious-import-handle-with-care.html?ref=sports
# http://www.nytimes.com/2016/01/18/sports/basketball/as-knicks-slip-kristaps-porzingis-learns-he-must-add-greed-to-his-game.html
# http://www.nytimes.com/2016/01/19/sports/tennis/ash-barty-left-pro-tennis-for-cricket-will-she-ever-return.html?ref=sports
# http://www.nytimes.com/2016/01/18/sports/as-track-atones-for-doping-scandals-some-athletes-seek-more-than-an-apology.html?ref=sports
# http://www.nytimes.com/2016/01/17/sports/ryan-hall-fastest-us-distance-runner-is-retiring.html?ref=sports
# http://www.nytimes.com/2016/01/17/sports/tennis/operating-on-a-shoestring-ireland-struggles-to-develop-first-rate-players.html?ref=sports
# http://www.nytimes.com/2016/01/16/sports/football/st-louis-should-be-glad-it-lost-the-rams.html?ref=sports
# http://www.nytimes.com/2016/01/16/sports/ncaafootball/the-41-season-at-plainfield-teachers-college-when-every-play-was-a-fake.html?ref=sports
# http://www.nytimes.com/2016/01/15/sports/baseball/cricket-player-kieran-powell-takes-a-swing-at-baseball.html?ref=sports
# http://www.nytimes.com/aponline/2016/01/21/sports/soccer/ap-soc-english-preview.html?ref=sports
# http://www.nytimes.com/reuters/2016/01/21/sports/olympics/21reuters-olympics-2024-rome-renzi.html?ref=sports
# http://www.nytimes.com/reuters/2016/01/21/sports/autoracing/21reuters-motor-racing-azerbaijan.html?ref=sports
# http://www.nytimes.com/aponline/2016/01/21/sports/ap-ski-wcup-womens-downhill-training.html?ref=sports
# http://www.nytimes.com/aponline/2016/01/21/sports/football/ap-fbn-relocation-rams-psl-lawsuit.html?ref=sports
# http://www.nytimes.com/2016/01/21/sports/basketball/how-the-nba-3-point-shot-went-from-gimmick-to-game-changer.html?src=me
# http://www.nytimes.com/2016/01/21/sports/football/among-nfl-coaches-a-lack-of-diversity-trickles-up.html?src=me
# http://www.nytimes.com/2016/01/16/sports/ncaafootball/the-41-season-at-plainfield-teachers-college-when-every-play-was-a-fake.html?src=me
# http://www.nytimes.com/2016/01/21/sports/hockey/john-scott-is-neither-in-the-nhl-nor-a-star.html?src=me
# http://www.nytimes.com/2016/01/21/sports/ncaabasketball/big-5-teams-cap-milestone-with-a-throwback-doubleheader.html?src=me
# http://www.nytimes.com/2016/01/20/sports/soccer/barcelona-sporting-club-ecuador.html?src=me
# http://www.nytimes.com/2016/01/21/sports/football/with-steelers-falling-short-mike-tomlin-gets-right-to-work.html?src=me
# http://www.nytimes.com/2016/01/20/sports/tennis/rafael-nadal-australian-open-first-round-loss.html?src=me
# http://www.nytimes.com/2016/01/20/sports/soccer/luis-suarez-from-villain-to-perfect-team-guy.html?src=me
# http://www.nytimes.com/2016/01/20/sports/ncaabasketball/five-teams-seek-to-end-ncaa-tournament-wait.html?src=me
# http://www.nytimes.com/2016/01/21/sports/basketball/how-the-nba-3-point-shot-went-from-gimmick-to-game-changer.html?src=mv
# http://www.nytimes.com/2016/01/21/sports/football/among-nfl-coaches-a-lack-of-diversity-trickles-up.html?src=mv
# http://www.nytimes.com/2016/01/21/sports/tennis/eugenie-bouchard-exits-australian-open-knowing-a-full-comeback-will-take-time.html?src=mv
# http://www.nytimes.com/2016/01/20/sports/soccer/barcelona-sporting-club-ecuador.html?src=mv
# http://www.nytimes.com/2016/01/21/sports/basketball/derrick-williams-new-york-knicks-beat-utah-jazz.html?src=mv
# http://www.nytimes.com/2016/01/20/sports/tennis/rafael-nadal-australian-open-first-round-loss.html?src=mv
# http://www.nytimes.com/aponline/2016/01/20/sports/tennis/ap-ten-australian-open.html?src=mv
# http://www.nytimes.com/2016/01/19/sports/football/nfl-playoffs-powerful-survivors-have-their-weaknesses.html?src=mv
# http://www.nytimes.com/2016/01/20/sports/basketball/cleveland-cavaliers-golden-state-warriors-34-points.html?src=mv
# http://www.nytimes.com/2016/01/16/sports/ncaafootball/the-41-season-at-plainfield-teachers-college-when-every-play-was-a-fake.html?src=mv
# /Users/swethakolalapudi/anaconda/envs/Python2/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
# Now let's collect these article summaries in an easy to classify form
articleSummaries = {}
for techUrlDictionary in [newYorkTimesTechArticles, washingtonPostTechArticles]:
    for articleUrl in techUrlDictionary:
        if techUrlDictionary[articleUrl][0] is not None:
            if len(techUrlDictionary[articleUrl][0]) > 0:
                fs = FrequencySummarizer()
                summary = fs.extractFeatures(techUrlDictionary[articleUrl],25)
                articleSummaries[articleUrl] = {'feature-vector': summary,
                                               'label': 'Tech'}
for nontechUrlDictionary in [newYorkTimesNonTechArticles, washingtonPostNonTechArticles]:
    for articleUrl in nontechUrlDictionary:
        if nontechUrlDictionary[articleUrl][0] is not None:
            if len(nontechUrlDictionary[articleUrl][0]) > 0:
                fs = FrequencySummarizer()
                summary = fs.extractFeatures(nontechUrlDictionary[articleUrl],25)
                articleSummaries[articleUrl] = {'feature-vector': summary,
                                               'label': 'Non-Tech'}

# %%
def getDoxyDonkeyText(testUrl,token):
    response = requests.get(testUrl)
    soup = BeautifulSoup(response.content)
    page = str(soup)
    title = soup.find("title").text
    mydivs = soup.findAll("div", {"class":token})
    text = ''.join(map(lambda p:p.text,mydivs))
    return text,title
    # our test instance, just like our training data, is nicely
    # setup as a (title,text) tuple

testUrl = "http://doxydonkey.blogspot.in"
testArticle = getDoxyDonkeyText(testUrl,"post-body")

fs = FrequencySummarizer()
testArticleSummary = fs.extractFeatures(testArticle, 25)

# %%
similarities = {}
for articleUrl in articleSummaries:
    oneArticleSummary = articleSummaries[articleUrl]['feature-vector']
    similarities[articleUrl] = len(set(testArticleSummary).intersection(set(oneArticleSummary)))

labels = defaultdict(int)    
knn = nlargest(5, similarities, key=similarities.get)
for oneNeighbor in knn:
    labels[articleSummaries[oneNeighbor]['label']] += 1

nlargest(1,labels,key=labels.get)
# Out:
# ['Tech']

# %%
cumulativeRawFrequencies = {'Tech':defaultdict(int),'Non-Tech':defaultdict(int)}
trainingData = {'Tech':newYorkTimesTechArticles,'Non-Tech':newYorkTimesNonTechArticles}
for label in trainingData:
    for articleUrl in trainingData[label]:
        if len(trainingData[label][articleUrl][0]) > 0:
            fs = FrequencySummarizer()
            rawFrequencies = fs.extractRawFrequencies(trainingData[label][articleUrl])
            for word in rawFrequencies:
                cumulativeRawFrequencies[label][word] += rawFrequencies[word]

# %%
techiness = 1.0
nontechiness = 1.0
for word in testArticleSummary:
    # for each 'feature' of the test instance - 
    if word in cumulativeRawFrequencies['Tech']:
        techiness *= 1e3*cumulativeRawFrequencies['Tech'][word] / float(sum(cumulativeRawFrequencies['Tech'].values()))
        # we multiply the techiness by the probability of this word
        # appearing in a tech article (based on the training data)
    else:
        techiness /= 1e3
        # THis is worth paying attention to. If the word does not appear
        # in the tech articles of the training data at all,we could simply
        # set that probability to zero - in fact doing so is the 'correct'
        # way mathematically, because that way all of the probabilities would
        # sum to 1. But that would lead to 'snap' decisions since the techiness
        # would instantaneously become 0. To prevent this, we decide to take
        # the probability as some very small number (here 1 in 1000, which is 
        # actually not all that low)
    # Now the exact same deal- but for the nontechiness. We are intentionally
    # copy-pasting code (not a great software development practice) in order
    # to make the logic very clear. Ideally, we would have created a function
    # and called it twice rather than copy-pasting this code. In any event..
    if word in cumulativeRawFrequencies['Non-Tech']:
        nontechiness *= 1e3*cumulativeRawFrequencies['Non-Tech'][word] / float(sum(cumulativeRawFrequencies['Non-Tech'].values()))
        # we multiply the techiness by the probability of this word
        # appearing in a tech article (based on the training data)
    else:
        nontechiness /= 1e3

# we are almost done! Now we simply need to scale the techiness 
# and non-techiness by the probabilities of overall techiness and
# non-techiness. THis is simply the number of words in the tech and 
# non-tech articles respectively, as a proportion of the total number
# of words
techiness *= float(sum(cumulativeRawFrequencies['Tech'].values())) / (float(sum(cumulativeRawFrequencies['Tech'].values())) + float(sum(cumulativeRawFrequencies['Non-Tech'].values())))
nontechiness *= float(sum(cumulativeRawFrequencies['Non-Tech'].values())) / (float(sum(cumulativeRawFrequencies['Tech'].values())) + float(sum(cumulativeRawFrequencies['Non-Tech'].values())))
if techiness > nontechiness:
    label = 'Tech'
else:
    label = 'Non-Tech'
print label, techiness, nontechiness
# Out:
# Tech 72842372.4825 1.31443515272e-18

# %%
def getAllDoxyDonkeyPosts(url,links):
    request = urllib2.Request(url)
    response = urllib2.urlopen(request)
    soup = BeautifulSoup(response)
    for a in soup.findAll('a'):
        try:
            url = a['href']
            title = a['title']
            if title == "Older Posts":
                print title, url
                links.append(url)
                getAllDoxyDonkeyPosts(url,links)
        except:
            title = ""
    return

# %%
blogUrl = "http://doxydonkey.blogspot.in"
links = []
getAllDoxyDonkeyPosts(blogUrl,links)
doxyDonkeyPosts = {}
for link in links:
    doxyDonkeyPosts[link] = getDoxyDonkeyText(link,'post-body')


documentCorpus = []
for onePost in doxyDonkeyPosts.values():
    documentCorpus.append(onePost[0])
# Out:
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2016-01-12T18:08:00-08:00&max-results=7
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2016-01-03T18:19:00-08:00&max-results=7&start=7&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-12-21T18:58:00-08:00&max-results=7&start=14&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-12-10T18:32:00-08:00&max-results=7&start=21&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-12-01T18:22:00-08:00&max-results=7&start=28&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-11-22T18:15:00-08:00&max-results=7&start=35&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-11-11T18:45:00-08:00&max-results=7&start=42&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-11-01T18:53:00-08:00&max-results=7&start=49&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-10-15T19:30:00-07:00&max-results=7&start=56&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-10-06T19:14:00-07:00&max-results=7&start=63&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-09-23T19:59:00-07:00&max-results=7&start=70&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-09-14T19:25:00-07:00&max-results=7&start=77&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-09-03T19:25:00-07:00&max-results=7&start=84&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-08-25T19:06:00-07:00&max-results=7&start=91&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-08-16T19:20:00-07:00&max-results=7&start=98&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-08-05T19:26:00-07:00&max-results=7&start=105&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-07-27T20:03:00-07:00&max-results=7&start=112&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-07-16T19:36:00-07:00&max-results=7&start=119&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-07-07T19:29:00-07:00&max-results=7&start=126&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-06-28T21:20:00-07:00&max-results=7&start=133&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-06-17T18:47:00-07:00&max-results=7&start=140&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-06-08T19:02:00-07:00&max-results=7&start=147&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-05-27T19:40:00-07:00&max-results=7&start=154&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-05-18T19:22:00-07:00&max-results=7&start=161&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-05-07T20:18:00-07:00&max-results=7&start=168&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-04-28T21:02:00-07:00&max-results=7&start=175&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-04-19T20:09:00-07:00&max-results=7&start=182&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-04-08T20:42:00-07:00&max-results=7&start=189&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-03-29T20:39:00-07:00&max-results=7&start=196&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-03-18T20:31:00-07:00&max-results=7&start=203&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-03-09T20:41:00-07:00&max-results=7&start=210&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-02-25T19:35:00-08:00&max-results=7&start=217&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-02-16T19:50:00-08:00&max-results=7&start=224&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-02-05T20:03:00-08:00&max-results=7&start=231&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-01-27T19:41:00-08:00&max-results=7&start=238&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-01-19T19:35:00-08:00&max-results=7&start=243&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2015-01-11T19:32:00-08:00&max-results=7&start=249&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2014-12-30T19:35:00-08:00&max-results=7&start=256&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2014-12-18T19:49:00-08:00&max-results=7&start=263&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2014-12-09T18:59:00-08:00&max-results=7&start=270&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2014-12-01T01:50:00-08:00&max-results=7&start=277&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2014-11-20T01:42:00-08:00&max-results=7&start=284&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2014-11-11T01:39:00-08:00&max-results=7&start=291&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2014-10-31T01:26:00-07:00&max-results=7&start=298&by-date=false
# Older Posts http://doxydonkey.blogspot.in/search?updated-max=2014-10-22T01:22:00-07:00&max-results=7&start=305&by-date=false

# %%
vectorizer = TfidfVectorizer(max_df=0.5,min_df=2,stop_words='english')
X = vectorizer.fit_transform(documentCorpus)
km = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 100, n_init = 1, verbose = True)
km.fit(X)

keywords = {}
for i,cluster in enumerate(km.labels_):
    oneDocument = documentCorpus[i]
    fs = FrequencySummarizer()
    summary = fs.extractFeatures((oneDocument,""),
                                100,
                                [u"according",u"also",u"billion",u"like",u"new", u"one",u"year",u"first",u"last"])
    if cluster not in keywords:
        keywords[cluster] = set(summary)
    else:
        keywords[cluster] = keywords[cluster].intersection(set(summary))
# Out:
# Initialization complete
# Iteration  0, inertia 66.984
# Iteration  1, inertia 34.907
# Converged at iteration 1
